# %%
import qsharp

# %%
dir(qsharp)
# Out:
# ['BitFlipNoise',
#  'DepolarizingNoise',
#  'Pauli',
#  'PauliNoise',
#  'PhaseFlipNoise',
#  'QSharpError',
#  'Result',
#  'ShotResult',
#  'StateDump',
#  'TargetProfile',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_ipython',
#  '_native',
#  '_qsharp',
#  'circuit',
#  'code',
#  'compile',
#  'dump_circuit',
#  'dump_machine',
#  'enable_classic_notebook_codemirror_mode',
#  'estimate',
#  'estimate_custom',
#  'estimator',
#  'eval',
#  'init',
#  'register_magic',
#  'run',
#  'set_classical_seed',
#  'set_quantum_seed',
#  'telemetry',
#  'telemetry_events']
